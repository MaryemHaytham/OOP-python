# %% [markdown]
# ### create calculator that can apply this operation in two numbers using opp

# %%
class Calculator:
    def __init__(self, num1, num2):
        self.num1 = num1
        self.num2 = num2

    def add(self):
        return self.num1 + self.num2

    def subtract(self):
        return self.num1 - self.num2

    def multiply(self):
        return self.num1 * self.num2

    def divide(self):
        if self.num2 != 0:
            return self.num1 / self.num2
        else:
            return "Error: Cannot divide by zero!"

    def is_even(self, num):
        return num % 2 == 0

    def is_odd(self, num):
        return num % 2 != 0

    def factorial(self, num):
        if num < 0:
            return "Error: Factorial is not defined for negative numbers!"
        elif num == 0 or num == 1:
            return 1
        else:
            result = 1
            for i in range(1, num + 1):
                result *= i
            return result

    def fibonacci(self, num):
        sequence = []
        if num == 0:
            return sequence
        elif num == 1:
            return [0]
        elif num == 2:
            return [0, 1]
        else:
            sequence = [0, 1]
            for i in range(2, num):
                sequence.append(sequence[-1] + sequence[-2])
            return sequence

# Create calculator instance and perform operations
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

calculator = Calculator(num1, num2)

operation = input("Choose an operation (add, subtract, multiply, divide, even, odd, factorial, fibonacci): ")

if operation == "add":
    result = calculator.add()
    print("Addition:", result)
elif operation == "subtract":
    result = calculator.subtract()
    print("Subtraction:", result)
elif operation == "multiply":
    result = calculator.multiply()
    print("Multiplication:", result)
elif operation == "divide":
    result = calculator.divide()
    print("Division:", result)
elif operation == "even":
    num = int(input("Enter a number to check if it's even: "))
    result = calculator.is_even(num)
    print(num, "is even:", result)
elif operation == "odd":
    num = int(input("Enter a number to check if it's odd: "))
    result = calculator.is_odd(num)
    print(num, "is odd:", result)
elif operation == "factorial":
    num = int(input("Enter a number to calculate its factorial: "))
    result = calculator.factorial(num)
    print("Factorial of", num, "is:", result)
elif operation == "fibonacci":
    num = int(input("Enter the length of the Fibonacci sequence to generate: "))
    result = calculator.fibonacci(num)
    print("Fibonacci sequence:", result)
else:
    print("Invalid operation selected.")
# Out:
# Enter the first number: 2
# Enter the second number: 2
# Choose an operation (add, subtract, multiply, divide, even, odd, factorial, fibonacci): add
# Addition: 4.0

# %% [markdown]
# ### create calculator that can apply this operation in two numbers or more using opp

# %%
class Calculator:
    def __init__(self, numbers):
        self.numbers = numbers

    def add(self):
        return sum(self.numbers)

    def subtract(self):
        result = self.numbers[0]
        for num in self.numbers[1:]:
            result -= num
        return result

    def multiply(self):
        result = self.numbers[0]
        for num in self.numbers[1:]:
            result *= num
        return result

    def divide(self):
        result = self.numbers[0]
        for num in self.numbers[1:]:
            if num != 0:
                result /= num
            else:
                return "Error: Cannot divide by zero!"
        return result

    def is_even(self, num):
        return num % 2 == 0

    def is_odd(self, num):
        return num % 2 != 0

    def factorial(self, num):
        if num < 0:
            return "Error: Factorial is not defined for negative numbers!"
        elif num == 0 or num == 1:
            return 1
        else:
            result = 1
            for i in range(1, num + 1):
                result *= i
            return result

    def fibonacci(self, num):
        sequence = []
        if num == 0:
            return sequence
        elif num == 1:
            return [0]
        elif num == 2:
            return [0, 1]
        else:
            sequence = [0, 1]
            for i in range(2, num):
                sequence.append(sequence[-1] + sequence[-2])
            return sequence

# Get input from user
numbers = []
num_count = int(input("Enter the count of numbers: "))
for i in range(num_count):
    num = float(input(f"Enter number {i+1}: "))
    numbers.append(num)

# Create calculator instance and perform operations
calculator = Calculator(numbers)

operation = input("Choose an operation (add, subtract, multiply, divide, even, odd, factorial, fibonacci): ")

if operation == "add":
    result = calculator.add()
    print("Addition:", result)
elif operation == "subtract":
    result = calculator.subtract()
    print("Subtraction:", result)
elif operation == "multiply":
    result = calculator.multiply()
    print("Multiplication:", result)
elif operation == "divide":
    result = calculator.divide()
    print("Division:", result)
elif operation == "even":
    num = int(input("Enter a number to check if it's even: "))
    result = calculator.is_even(num)
    print(num, "is even:", result)
elif operation == "odd":
    num = int(input("Enter a number to check if it's odd: "))
    result = calculator.is_odd(num)
    print(num, "is odd:", result)
elif operation == "factorial":
    num = int(input("Enter a number to calculate its factorial: "))
    result = calculator.factorial(num)
    print("Factorial of", num, "is:", result)
elif operation == "fibonacci":
    num = int(input("Enter the length of the Fibonacci sequence to generate: "))
    result = calculator.fibonacci(num)
    print("Fibonacci sequence:", result)
else:
    print("Invalid operation selected.")
# Out:
# Enter the count of numbers: 5
# Enter number 1: 1
# Enter number 2: 2
# Enter number 3: 3
# Enter number 4: 4
# Enter number 5: 5
# Choose an operation (add, subtract, multiply, divide, even, odd, factorial, fibonacci): multiply
# Multiplication: 120.0

# %% [markdown]
# ### Task 3: Rectangle class:
# Write a Rectangle class in Python language, allowing you to build a rectangle
# with length and width attributes. 2. Create a Perimeter() method to calculate the perimeter of the rectangle and a Area() method to calculate the area of the rectangle. 3. Create a method display() that display the length, width, perimeter and area of an object created using an instantiation on rectangle class. 4. Create a Parallelepipede child class inheriting from the Rectangle class and with a height attribute and another Volume() method to calculate the volume of the Parallelepiped

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def perimeter(self):
        return 2 * (self.length + self.width)

    def area(self):
        return self.length * self.width

    def display(self):
        print("Rectangle:")
        print("Length:", self.length)
        print("Width:", self.width)
        print("Perimeter:", self.perimeter())
        print("Area:", self.area())


class Parallelepipede(Rectangle):
    def __init__(self, length, width, height):
        super().__init__(length, width)
        self.height = height

    def volume(self):
        return self.length * self.width * self.height

    def display(self):
        print("Parallelepipede:")
        print("Length:", self.length)
        print("Width:", self.width)
        print("Height:", self.height)
        print("Perimeter:", self.perimeter())
        print("Area:", self.area())
        print("Volume:", self.volume())


# Create a rectangle object
length = float(input("Enter the length of the rectangle: "))
width = float(input("Enter the width of the rectangle: "))

rectangle = Rectangle(length, width)
rectangle.display()

print()

# Create a parallelepiped object
height = float(input("Enter the height of the parallelepiped: "))

parallelepiped = Parallelepipede(length, width, height)
parallelepiped.display()
# Out:
# Enter the length of the rectangle: 3
# Enter the width of the rectangle: 5
# Rectangle:
# Length: 3.0
# Width: 5.0
# Perimeter: 16.0
# Area: 15.0
#
# Enter the height of the parallelepiped: 5
# Parallelepipede:
# Length: 3.0
# Width: 5.0
# Height: 5.0
# Perimeter: 16.0
# Area: 15.0
# Volume: 75.0
